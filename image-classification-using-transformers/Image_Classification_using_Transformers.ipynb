# %%
from transformers import ViTImageProcessor, ViTForImageClassification
from PIL import Image
import requests

url = 'http://images.cocodataset.org/val2017/000000039769.jpg'
image = Image.open(requests.get(url, stream=True).raw)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %%
processor = ViTImageProcessor.from_pretrained('google/vit-base-patch16-224')
model = ViTForImageClassification.from_pretrained('google/vit-base-patch16-224')

inputs = processor(images=image, return_tensors="pt")
outputs = model(**inputs)
logits = outputs.logits
# model predicts one of the 1000 ImageNet classes
predicted_class_idx = logits.argmax(-1).item()
print("Predicted class:", model.config.id2label[predicted_class_idx])
# Out:
# Predicted class: Egyptian cat

# %%
def predict(image):
  inputs = processor(images=image, return_tensors="pt")
  outputs = model(**inputs)
  logits = outputs.logits
  # model predicts one of the 1000 ImageNet classes
  predicted_class_idx = logits.argmax(-1).item()
  print("Predicted class:", model.config.id2label[predicted_class_idx])

# %%
goku = "https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/09175786-905e-45cd-967a-9b2f0575e96e/def9hac-5174c669-055d-40e8-803b-fc6b9448a439.jpg/v1/fill/w_1280,h_1106,q_75,strp/goku_ui_by_pepecarcas01_def9hac-fullview.jpg?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..R0u0a4Kpd_0pPeLYNcC9NqvinhtBgGWOvSiITMloR88"
goku_image = Image.open(requests.get(goku, stream=True).raw)
goku_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x1106>

# %%
predict(goku_image)
# Out:
# Predicted class: isopod

# %%
google_logo = "https://1000logos.net/wp-content/uploads/2016/11/Google-Logo-2013.jpg"

# %%
google_logo_image = Image.open(requests.get(google_logo, stream=True).raw)
google_logo_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x450>

# %%
predict(google_logo_image)
# Out:
# Predicted class: web site, website, internet site, site
